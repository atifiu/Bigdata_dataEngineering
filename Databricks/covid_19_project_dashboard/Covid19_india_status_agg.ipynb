# %% [markdown]
# This notebook uses data world covid 19 data which is fetch from https://www.mygov.in/covid-19 website
#  This is daily aggregate data statewise updated daily around 12 noon.

# %%
# Reading the data directly from data.world url as a workaround because spark dataframe is unable to read data directly 
# from url and hence pandas is used to convert csv to pandas df.
import pandas as pd
df = pd.read_csv('https://query.data.world/s/irxczuog4sdx6zhyxfu62i7lmrdoxj')
df.head()
#df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>StateCode</th>
#       <th>State Name</th>
#       <th>Active Cases (Yesterday)</th>
#       <th>Positive Cases (Yesterday)</th>
#       <th>Cured Cases (Yesterday)</th>
#       <th>Death Cases (Yesterday)</th>
#       <th>Active Cases (Today)</th>
#       <th>Positive Cases (Today)</th>
#       <th>Cured Cases (Today)</th>
#       <th>Death Cases (Today)</th>
#       <th>Last Updated (IST)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>35</td>
#       <td>Andaman and Nicobar Islands</td>
#       <td>44</td>
#       <td>10586</td>
#       <td>10413</td>
#       <td>129</td>
#       <td>38</td>
#       <td>10590</td>
#       <td>10423</td>
#       <td>129</td>
#       <td>26-Aug-2022 11:23:57</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>28</td>
#       <td>Andhra Pradesh</td>
#       <td>965</td>
#       <td>2336266</td>
#       <td>2320568</td>
#       <td>14733</td>
#       <td>901</td>
#       <td>2336386</td>
#       <td>2320752</td>
#       <td>14733</td>
#       <td>26-Aug-2022 11:23:57</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>12</td>
#       <td>Arunachal Pradesh</td>
#       <td>96</td>
#       <td>66599</td>
#       <td>66207</td>
#       <td>296</td>
#       <td>84</td>
#       <td>66614</td>
#       <td>66234</td>
#       <td>296</td>
#       <td>26-Aug-2022 11:23:57</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>18</td>
#       <td>Assam</td>
#       <td>2926</td>
#       <td>743801</td>
#       <td>732846</td>
#       <td>8029</td>
#       <td>2977</td>
#       <td>743934</td>
#       <td>732927</td>
#       <td>8030</td>
#       <td>26-Aug-2022 11:23:57</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10</td>
#       <td>Bihar</td>
#       <td>805</td>
#       <td>847221</td>
#       <td>834124</td>
#       <td>12292</td>
#       <td>848</td>
#       <td>847411</td>
#       <td>834271</td>
#       <td>12292</td>
#       <td>26-Aug-2022 11:23:57</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#converting pandas dataframe df to spark dataframe sparkDF
df=spark.createDataFrame(df) 
df.printSchema()
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- StateCode: long (nullable = true)
# -- State Name: string (nullable = true)
# -- Active Cases (Yesterday): long (nullable = true)
# -- Positive Cases (Yesterday): long (nullable = true)
# -- Cured Cases (Yesterday): long (nullable = true)
# -- Death Cases (Yesterday): long (nullable = true)
# -- Active Cases (Today): long (nullable = true)
# -- Positive Cases (Today): long (nullable = true)
# -- Cured Cases (Today): long (nullable = true)
# -- Death Cases (Today): long (nullable = true)
# -- Last Updated (IST): string (nullable = true)
#
# +---------+--------------------+------------------------+--------------------------+-----------------------+-----------------------+--------------------+----------------------+-------------------+-------------------+--------------------+
# StateCode|          State Name|Active Cases (Yesterday)|Positive Cases (Yesterday)|Cured Cases (Yesterday)|Death Cases (Yesterday)|Active Cases (Today)|Positive Cases (Today)|Cured Cases (Today)|Death Cases (Today)|  Last Updated (IST)|
# +---------+--------------------+------------------------+--------------------------+-----------------------+-----------------------+--------------------+----------------------+-------------------+-------------------+--------------------+

# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/covid19_india_aggregate/</td><td>covid19_india_aggregate/</td><td>0</td><td>1661513998573</td></tr></tbody></table></div>

# %%
# to create spark DF from csv file already downloaded but since this method is replaced with
# pandas df and then converted it to spark df, it has been commented now
# File location and type
#file_location = "/FileStore/tables/India_COVID_19_Status.csv"

#file_type = "csv"

# CSV options
#infer_schema = "true"
#first_row_is_header = "true"
#delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
#df = spark.read.format(file_type) \
  #.option("inferSchema", infer_schema) \
  #.option("header", first_row_is_header) \
  #.option("sep", delimiter) \
  #.load(file_location)

#print(type(df))

#display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [&#39;StateCode&#39;,
#  &#39;State Name&#39;,
#  &#39;Active Cases (Yesterday)&#39;,
#  &#39;Positive Cases (Yesterday)&#39;,
#  &#39;Cured Cases (Yesterday)&#39;,
#  &#39;Death Cases (Yesterday)&#39;,
#  &#39;Active Cases (Today)&#39;,
#  &#39;Positive Cases (Today)&#39;,
#  &#39;Cured Cases (Today)&#39;,
#  &#39;Death Cases (Today)&#39;,
#  &#39;Last Updated (IST)&#39;]</div>

# %%
#Create the final df to be saved into the covid19_india_aggregate_data table.
# new columns are derived which indicates the covid status of new cases/deaths/recoveries reported on previous day 
# along with aggregate data.
from pyspark.sql.functions import round

df = df.select(df["State Name"].alias("State_Name"), 
               df["Positive Cases (Today)"].alias("Total_Cases"), 
               df["Active Cases (Today)"].alias("Total_Active_Cases"),
               df["Cured Cases (Today)"].alias("Total_Recoveries"), 
               df["Death Cases (Today)"].alias("Total_Deaths"),
               (df["Positive Cases (Today)"] - df["Positive Cases (Yesterday)"]).alias("New_Cases"),
               (df["Active Cases (Today)"] - df["Active Cases (Yesterday)"]).alias("New_Active_Cases"),
               (df["Cured Cases (Today)"] - df["Cured Cases (Yesterday)"]).alias("New_Recoveries"), 
               (df["Death Cases (Today)"] - df["Death Cases (Yesterday)"]).alias("New_Deaths"), 
               (round((df["Active Cases (Today)"]/df["Positive Cases (Today)"])*100)).alias("Active_ratio"),
               df["Last Updated (IST)"].alias("Last_Updated_IST") )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# This will only be used for inserting the data first time when table does not exist
# We will be appending the data rather than overwritining so that previous days aggregate is 
# also present for any furture analysis. using last_updated column we can identify data belongs to which date.
# df.write.mode("append").saveAsTable("covid19_india_aggregate")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#create a dataframe of existing data in covid19_india_aggregate
#df_temp = spark.sql("select * from covid19_india_aggregate")
#df_temp.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# create new df after union of new data df and existing data in table covid19_india_aggregate
df_final = df.union(spark.sql("select * from covid19_india_aggregate")).drop_duplicates()
df_final.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: 72</div>

# %%
display(df_final.orderBy("State_Name"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>State_Name</th><th>Total_Cases</th><th>Total_Active_Cases</th><th>Total_Recoveries</th><th>Total_Deaths</th><th>New_Cases</th><th>New_Active_Cases</th><th>New_Recoveries</th><th>New_Deaths</th><th>Active_ratio</th><th>Last_Updated_IST</th></tr></thead><tbody><tr><td>Andaman and Nicobar Islands</td><td>10590</td><td>38</td><td>10423</td><td>129</td><td>4</td><td>-6</td><td>10</td><td>0</td><td>0.0</td><td>26-Aug-2022 11:23:57</td></tr><tr><td>Andaman and Nicobar Islands</td><td>10586</td><td>44</td><td>10413</td><td>129</td><td>7</td><td>-1</td><td>8</td><td>0</td><td>0.0</td><td>25-Aug-2022 21:43:06</td></tr><tr><td>Andhra Pradesh</td><td>2336266</td><td>965</td><td>2320568</td><td>14733</td><td>136</td><td>-74</td><td>210</td><td>0</td><td>0.0</td><td>25-Aug-2022 21:43:06</td></tr><tr><td>Andhra Pradesh</td><td>2336386</td><td>901</td><td>2320752</td><td>14733</td><td>120</td><td>-64</td><td>184</td><td>0</td><td>0.0</td><td>26-Aug-2022 11:23:57</td></tr><tr><td>